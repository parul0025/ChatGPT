# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque

from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

domain = "openai.com" # <- put your domain to be crawled
full_url = "https://openai.com/" # <- put your domain to be crawled with https or http

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        # Create a list to store the hyperlinks
        self.hyperlinks = []

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)

        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

# %%
# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser()
    parser.feed(html)

    return parser.hyperlinks

# %%
# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))

# %%
def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])
    print(queue)

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])
    print(seen)

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress

        # Save text from the url to a <url>.txt file
        try:
            with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w", encoding="UTF-8") as f:

                # Get the text from the URL using BeautifulSoup
                soup = BeautifulSoup(requests.get(url).text, "html.parser")

                # Get the text but remove the tags
                text = soup.get_text()

                # If the crawler gets to a page that requires JavaScript, it will stop the crawl
                if ("You need to enable JavaScript to run this app." in text):
                    print("Unable to parse page " + url + " due to JavaScript being required")

                # Otherwise, write the text to the file in the text directory
                f.write(text)

            # Get the hyperlinks from the URL and add them to the queue
            print(local_domain,url)
            for link in get_domain_hyperlinks(local_domain, url):
                if link not in seen:
                    queue.append(link)
                    seen.add(link)
        except:
            continue

crawl(full_url)
# Out:
# deque(['https://openai.com/'])
# {'https://openai.com/'}
# https://openai.com/
# openai.com https://openai.com/
# https://openai.com/research/whisper
# openai.com https://openai.com/research/whisper
# https://openai.com/research?contentTypes=publication
# https://openai.com/research?topics=transformers
# https://openai.com/research?topics=speech-recognition
# https://openai.com/research?contentTypes=milestone
# https://openai.com/research?models=whisper
# https://openai.com/research?topics=open-source
# https://openai.com/research?contentTypes=release
# https://openai.com/research/whisper#content
# openai.com https://openai.com/research/whisper#content
# https://openai.com/product/gpt-4
# openai.com https://openai.com/product/gpt-4
# https://openai.com/contributions/gpt-4
# openai.com https://openai.com/contributions/gpt-4
# https://openai.com/contributions/gpt-4#content
# openai.com https://openai.com/contributions/gpt-4#content
# https://openai.com/waitlist/gpt-4-api
# openai.com https://openai.com/waitlist/gpt-4-api
# https://openai.com/policies/usage-policies
# openai.com https://openai.com/policies/usage-policies
# https://openai.com/policies/usage-policies#content
# openai.com https://openai.com/policies/usage-policies#content
# https://openai.com/api/policies/sharing-publication
# openai.com https://openai.com/api/policies/sharing-publication
# https://openai.com/policies/coordinated-vulnerability-disclosure-policy
# openai.com https://openai.com/policies/coordinated-vulnerability-disclosure-policy
# https://openai.com/policies/coordinated-vulnerability-disclosure-policy#content
# openai.com https://openai.com/policies/coordinated-vulnerability-disclosure-policy#content
# https://openai.com/policies/terms-of-use
# openai.com https://openai.com/policies/terms-of-use
# https://openai.com/policies/terms-of-use#content
# openai.com https://openai.com/policies/terms-of-use#content
# https://openai.com/policies/sharing-publication-policy
# openai.com https://openai.com/policies/sharing-publication-policy
# https://openai.com/policies/service-terms
# openai.com https://openai.com/policies/service-terms
# https://openai.com/policies/service-terms#content
# openai.com https://openai.com/policies/service-terms#content
# https://openai.com/blog/openai-codex
# openai.com https://openai.com/blog/openai-codex
# https://openai.com/blog/openai-codex#OpenAI
# openai.com https://openai.com/blog/openai-codex#OpenAI
# https://openai.com/blog/openai-codex#content
# openai.com https://openai.com/blog/openai-codex#content
# https://openai.com/blog?authors=openai
# https://openai.com/blog/openai-codex#GregBrockman
# openai.com https://openai.com/blog/openai-codex#GregBrockman
# https://openai.com/blog?topics=announcements
# https://openai.com/blog?authors=greg-brockman
# https://openai.com/blog/openai-codex#WojciechZaremba
# openai.com https://openai.com/blog/openai-codex#WojciechZaremba
# https://openai.com/blog?authors=wojciech-zaremba
# https://openai.com/blog?topics=product
# https://openai.com/policies/sharing-publication-policy#content
# openai.com https://openai.com/policies/sharing-publication-policy#content
# https://openai.com/form/researcher-access-program
# openai.com https://openai.com/form/researcher-access-program
# https://openai.com/form/researcher-access-program#content
# openai.com https://openai.com/form/researcher-access-program#content
# https://openai.com/policies/sharing-publication-policy#research
# openai.com https://openai.com/policies/sharing-publication-policy#research
# https://openai.com/waitlist/gpt-4-api#content
# openai.com https://openai.com/blog/discovering-the-minutiae-of-backend-systems#content
# https://openai.com/blog?topics=culture-and-careers
# https://openai.com/blog/discovering-the-minutiae-of-backend-systems#OpenAI
# openai.com https://openai.com/blog/discovering-the-minutiae-of-backend-systems#OpenAI
# https://openai.com/blog/the-power-of-continuous-learning
# openai.com https://openai.com/blog/the-power-of-continuous-learning
# https://openai.com/blog/the-power-of-continuous-learning#OpenAI
# openai.com https://openai.com/blog/the-power-of-continuous-learning#OpenAI
# https://openai.com/blog/the-power-of-continuous-learning#content
# openai.com https://openai.com/blog/the-power-of-continuous-learning#content
# https://openai.com/blog/solving-rubiks-cube
# openai.com https://openai.com/blog/solving-rubiks-cube
# https://openai.com/blog/openai-five
# openai.com https://openai.com/blog/openai-five
# https://openai.com/research/openai-five#thegames
# openai.com https://openai.com/research/openai-five#thegames
# https://openai.com/research?authors=michael-petrov
# https://openai.com/research?authors=christopher-berner
# https://openai.com/research?authors=przemyslaw-debiak
# https://openai.com/research?topics=software-engineering
# https://openai.com/research?authors=susan-zhang
# https://openai.com/research?authors=jack-clark
# https://openai.com/research/learning-a-hierarchy
# openai.com https://openai.com/research/learning-a-hierarchy
# https://openai.com/research/learning-a-hierarchy#content
# openai.com https://openai.com/research/learning-a-hierarchy#content
# https://openai.com/research?authors=kevin-frans
# https://openai.com/research?authors=jonathan-ho
# https://openai.com/research?authors=pieter-abbeel
# https://openai.com/research?authors=peter-chen
# https://openai.com/research?topics=self-play
# https://openai.com/research?topics=dota-2
# https://openai.com/research/openai-baselines-ppo
# openai.com https://openai.com/research/openai-baselines-ppo
# https://openai.com/research?authors=prafulla-dhariwal
# https://openai.com/research?topics=policy-optimization
# https://openai.com/research/openai-baselines-ppo#content
# openai.com https://openai.com/research/openai-baselines-ppo#content
# https://openai.com/research/roboschool
# openai.com https://openai.com/research/roboschool
# https://openai.com/research/roboschool#content
# openai.com https://openai.com/research/roboschool#content
# https://openai.com/research?topics=environments
# https://openai.com/research?authors=oleg-klimov
# https://openai.com/research?authors=scott-gray
# https://openai.com/research/generalizing-from-simulation
# openai.com https://openai.com/research/generalizing-from-simulation
# https://openai.com/research?authors=lerrel-pinto
# https://openai.com/research?authors=josh-tobin
# https://openai.com/research?authors=alex-ray
# https://openai.com/blog/generalizing-from-simulation/#pusher_fail
# openai.com https://openai.com/blog/generalizing-from-simulation/#pusher_fail
# https://openai.com/research?authors=xue-bin-peng
# https://openai.com/research/learning-from-human-preferences
# openai.com https://openai.com/research/learning-from-human-preferences
# https://openai.com/research?topics=safety-alignment
# https://openai.com/blog/deep-reinforcement-learning-from-human-preferences/#bflip
# openai.com https://openai.com/blog/deep-reinforcement-learning-from-human-preferences/#bflip
# https://openai.com/research?topics=human-feedback
# https://openai.com/research?authors=dario-amodei
# https://openai.com/research/learning-from-human-preferences#content
# openai.com https://openai.com/research/learning-from-human-preferences#content
# https://openai.com/research/generalizing-from-simulation#content
# openai.com https://openai.com/research/generalizing-from-simulation#content
# https://openai.com/research?authors=filip-wolski
# https://openai.com/research?authors=jakub-pachocki
# https://openai.com/research/unsupervised-sentiment-neuron
# openai.com https://openai.com/research/unsupervised-sentiment-neuron
# https://openai.com/research/unsupervised-sentiment-neuron#content
# openai.com https://openai.com/research/unsupervised-sentiment-neuron#content
# https://openai.com/blog/unsupervised-sentiment-neuron/#methodology
# openai.com https://openai.com/blog/unsupervised-sentiment-neuron/#methodology
# https://openai.com/blog/unsupervised-sentiment-neuron/#sentimentneuron
# openai.com https://openai.com/blog/unsupervised-sentiment-neuron/#sentimentneuron
# https://openai.com/research?topics=language
# https://openai.com/research/block-sparse-gpu-kernels#small-world-lstms
# openai.com https://openai.com/research/block-sparse-gpu-kernels#small-world-lstms
# https://openai.com/research/block-sparse-gpu-kernels#content
# openai.com https://openai.com/research/block-sparse-gpu-kernels#content
# https://openai.com/research?topics=sparsity
# https://openai.com/research/sparse-transformer#content
# openai.com https://openai.com/research/sparse-transformer#content
# https://openai.com/research?authors=rewon-child
# https://openai.com/research?models=musenet
# https://openai.com/research/musenet#content
# openai.com https://openai.com/research/musenet#content
# https://openai.com/research?topics=audio-generation
# https://openai.com/blog/better-language-models
# openai.com https://openai.com/blog/better-language-models
# https://openai.com/research?authors=jeffrey-wu
# https://openai.com/research/better-language-models#content
# openai.com https://openai.com/research/better-language-models#content
# https://openai.com/research?authors=miles-brundage
# https://openai.com/research/language-unsupervised
# openai.com https://openai.com/research/language-unsupervised
# https://openai.com/research/language-unsupervised#content
# openai.com https://openai.com/research/language-unsupervised#content
# https://openai.com/research?models=gpt
# https://openai.com/research?authors=david-lansky
# https://openai.com/research?authors=amanda-askell
# https://openai.com/research?authors=daniella-amodei
# https://openai.com/blog/openai-residency#OpenAI
# openai.com https://openai.com/blog/openai-residency#OpenAI
# https://openai.com/blog/openai-residency#content
# openai.com https://openai.com/blog/openai-residency#content
# https://openai.com/interview-guide
# openai.com https://openai.com/interview-guide
# https://openai.com/interview-guide#content
# openai.com https://openai.com/interview-guide#content
# https://openai.com/research/image-gpt#introduction
# openai.com https://openai.com/research/image-gpt#introduction
# https://openai.com/blog/image-gpt/#samples
# openai.com https://openai.com/blog/image-gpt/#samples
# https://openai.com/research/image-gpt#limitations
# openai.com https://openai.com/research/image-gpt#limitations
# https://openai.com/research?topics=representation-learning
# https://openai.com/research?models=gpt-2
# https://openai.com/careers/software-engineer-security
# openai.com https://openai.com/careers/software-engineer-security
# https://openai.com/careers/software-engineer-security#content
# openai.com https://openai.com/careers/software-engineer-security#content
# https://openai.com/careers/search
# openai.com https://openai.com/careers/search
# https://openai.com/careers/software-engineer-model-inference-2
# openai.com https://openai.com/careers/software-engineer-model-inference-2
# https://openai.com/careers/software-engineer-model-inference-2#content
# openai.com https://openai.com/careers/software-engineer-model-inference-2#content
# https://openai.com/careers/full-stack-developer-communications-design
# openai.com https://openai.com/careers/full-stack-developer-communications-design
# https://openai.com/careers/full-stack-developer-communications-design#content
# openai.com https://openai.com/careers/full-stack-developer-communications-design#content
# https://openai.com/careers/policy-research-scientist-geopolitics
# openai.com https://openai.com/careers/policy-research-scientist-geopolitics
# https://openai.com/blog/dall-e-introducing-outpainting
# openai.com https://openai.com/blog/dall-e-introducing-outpainting
# https://openai.com/blog/dall-e-introducing-outpainting#content
# openai.com https://openai.com/blog/dall-e-introducing-outpainting#content
# https://openai.com/blog/dall-e-introducing-outpainting#OpenAI
# openai.com https://openai.com/blog/dall-e-introducing-outpainting#OpenAI
# https://openai.com/product/dall-e-2#content
# openai.com https://openai.com/product/dall-e-2#content
# https://openai.com/blog/dall-e-api-now-available-in-public-beta
# openai.com https://openai.com/blog/dall-e-api-now-available-in-public-beta
# https://openai.com/blog/dall-e-api-now-available-in-public-beta#content
# openai.com https://openai.com/blog/dall-e-api-now-available-in-public-beta#content
# https://openai.com/blog/dall-e-2-extending-creativity
# openai.com https://openai.com/blog/dall-e-2-extending-creativity
# https://openai.com/blog/dall-e-2-extending-creativity#OpenAI
# openai.com https://openai.com/blog/dall-e-2-extending-creativity#OpenAI
# https://openai.com/blog?topics=community
# https://openai.com/blog/dall-e-2-extending-creativity#content
# openai.com https://openai.com/blog/dall-e-2-extending-creativity#content
# https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2
# openai.com https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2
# https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2#OpenAI
# openai.com https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2#OpenAI
# https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2#content
# openai.com https://openai.com/blog/reducing-bias-and-improving-safety-in-dall-e-2#content
# https://openai.com/research/dall-e-2-pre-training-mitigations#content
# openai.com https://openai.com/research/dall-e-2-pre-training-mitigations#content
# https://openai.com/blog/clip
# openai.com https://openai.com/blog/clip
# https://openai.com/research?authors=jong-wook-kim
# https://openai.com/research?topics=supervised-learning
# https://openai.com/research?models=clip
# https://openai.com/research?topics=contrastive-learning
# https://openai.com/research/clip#content
# openai.com https://openai.com/research/clip#content
# https://openai.com/safety#content
# openai.com https://openai.com/safety#content
# https://openai.com/research/language-model-safety-and-misuse
# openai.com https://openai.com/research/language-model-safety-and-misuse
# https://openai.com/blog/best-practices-for-deploying-language-models
# openai.com https://openai.com/blog/best-practices-for-deploying-language-models
# https://openai.com/blog?topics=safety-alignment
# https://openai.com/blog/best-practices-for-deploying-language-models#OpenAI
# openai.com https://openai.com/blog/best-practices-for-deploying-language-models#OpenAI
# https://openai.com/blog/best-practices-for-deploying-language-models#content
# openai.com https://openai.com/blog/best-practices-for-deploying-language-models#content
# https://openai.com/blog/our-approach-to-alignment-research
# openai.com https://openai.com/blog/our-approach-to-alignment-research
# https://openai.com/blog/our-approach-to-alignment-research#JeffreyWu
# openai.com https://openai.com/blog/our-approach-to-alignment-research#JeffreyWu
# https://openai.com/blog/summarizing-books
# openai.com https://openai.com/blog/summarizing-books
# https://openai.com/research?models=gpt-3
# https://openai.com/blog/learning-to-summarize-with-human-feedback
# openai.com https://openai.com/blog/learning-to-summarize-with-human-feedback
# https://openai.com/research?authors=chelsea-voss
# https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf1
# openai.com https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf1
# https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf7
# openai.com https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf7
# https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf20
# openai.com https://openai.com/blog/learning-to-summarize-with-human-feedback/#rf20
# https://openai.com/blog/fine-tuning-gpt-2
# openai.com https://openai.com/blog/fine-tuning-gpt-2
# https://openai.com/research/gpt-2-6-month-follow-up
# openai.com https://openai.com/research/gpt-2-6-month-follow-up
# https://openai.com/blog/better-language-models/#update
# openai.com https://openai.com/blog/better-language-models/#update
# https://openai.com/research/gpt-2-6-month-follow-up#content
# openai.com https://openai.com/research/gpt-2-6-month-follow-up#content
# https://openai.com/research?authors=tom-brown
# https://openai.com/research/debate
# openai.com https://openai.com/research/debate
# https://openai.com/research/debate#content
# openai.com https://openai.com/research/debate#content
# https://openai.com/research?authors=geoffrey-irving
# https://openai.com/research/learning-complex-goals-with-iterated-amplification
# openai.com https://openai.com/research/learning-complex-goals-with-iterated-amplification
# https://openai.com/research/learning-complex-goals-with-iterated-amplification#content
# openai.com https://openai.com/research/learning-complex-goals-with-iterated-amplification#content
# https://openai.com/research/fine-tuning-gpt-2#content
# openai.com https://openai.com/research/fine-tuning-gpt-2#content
# https://openai.com/research?authors=daniel-ziegler
# https://openai.com/research/learning-to-summarize-with-human-feedback#content
# openai.com https://openai.com/research/learning-to-summarize-with-human-feedback#content
# https://openai.com/research?authors=long-ouyang
# https://openai.com/research?authors=nisan-stiennon
# https://openai.com/research/summarizing-books#content
# openai.com https://openai.com/research/summarizing-books#content
# https://openai.com/research?topics=summarization
# https://openai.com/research?authors=ryan-lowe
# https://openai.com/blog?authors=john-schulman-2
# https://openai.com/blog/our-approach-to-alignment-research#JohnSchulman
# openai.com https://openai.com/blog/our-approach-to-alignment-research#JohnSchulman
# https://openai.com/blog?authors=jeffrey-wu
# https://openai.com/blog/amplifying-ai-training
# openai.com https://openai.com/blog/amplifying-ai-training
# https://openai.com/blog/instruction-following/#limitations
# openai.com https://openai.com/blog/instruction-following/#limitations
# https://openai.com/research/instruction-following#content
# openai.com https://openai.com/research/instruction-following#content
# https://openai.com/blog/deep-reinforcement-learning-from-human-preferences
# openai.com https://openai.com/blog/deep-reinforcement-learning-from-human-preferences
# https://openai.com/blog/our-approach-to-alignment-research#content
# openai.com https://openai.com/blog/our-approach-to-alignment-research#content
# https://openai.com/blog/critiques
# openai.com https://openai.com/blog/critiques
# https://openai.com/research?authors=catherine-yeh
# https://openai.com/research/critiques#content
# openai.com https://openai.com/research/critiques#content
# https://openai.com/research?authors=william-saunders
# https://openai.com/blog/debate
# openai.com https://openai.com/blog/debate
# https://openai.com/blog/openai-api
# openai.com https://openai.com/blog/openai-api
# https://openai.com/blog/openai-lp
# openai.com https://openai.com/blog/openai-lp
# https://openai.com/blog/openai-scholars
# openai.com https://openai.com/blog/openai-scholars
# https://openai.com/blog/openai-scholars#LarissaSchiavo
# openai.com https://openai.com/blog/openai-scholars#LarissaSchiavo
# openai.com https://openai.com/blog/economic-impacts#TynaEloundou
# https://openai.com/blog?authors=sam-manning
# https://openai.com/blog/economic-impacts#content
# openai.com https://openai.com/blog/economic-impacts#content
# https://openai.com/blog?authors=tyna-eloundou
# https://openai.com/blog/economic-impacts#PamelaMishkin
# openai.com https://openai.com/blog/economic-impacts#PamelaMishkin
# https://openai.com/blog?authors=pamela-mishkin
# https://openai.com/blog/economic-impacts#SamManning
# openai.com https://openai.com/blog/economic-impacts#SamManning
# https://openai.com/blog/language-model-safety-and-misuse/#misuse
# openai.com https://openai.com/blog/language-model-safety-and-misuse/#misuse
# https://openai.com/blog/language-model-safety-and-misuse/#risk-impact-measurement
# openai.com https://openai.com/blog/language-model-safety-and-misuse/#risk-impact-measurement
# https://openai.com/research?authors=gretchen-krueger
# https://openai.com/blog/cooperation-on-safety
# openai.com https://openai.com/blog/cooperation-on-safety
# https://openai.com/research?authors=katie-mayer
# https://openai.com/blog/gpt-3-apps
# openai.com https://openai.com/blog/gpt-3-apps
# https://openai.com/blog/gpt-3-apps#OpenAI
# openai.com https://openai.com/blog/gpt-3-apps#OpenAI
# https://openai.com/jobs/#open
# openai.com https://openai.com/jobs/#open
# https://openai.com/blog/gpt-3-apps#content
# openai.com https://openai.com/blog/gpt-3-apps#content
# https://openai.com/blog/gpt-3-apps#AshleyPilipiszyn
# openai.com https://openai.com/blog/gpt-3-apps#AshleyPilipiszyn
# https://openai.com/blog/requests-for-research-2
# openai.com https://openai.com/blog/requests-for-research-2
# https://openai.com/research?authors=tyna-eloundou
# https://openai.com/blog/webgpt
# openai.com https://openai.com/blog/webgpt
# https://openai.com/research?authors=jacob-hilton
# https://openai.com/blog/webgpt/#samples
# openai.com https://openai.com/blog/webgpt/#samples
# https://openai.com/blog/webgpt/#rf4
# openai.com https://openai.com/blog/webgpt/#rf4
# https://openai.com/research?authors=reiichiro-nakano
# https://openai.com/research?authors=suchir-balaji
# https://openai.com/research/webgpt#content
# openai.com https://openai.com/research/webgpt#content
# https://openai.com/research?authors=steven-adler
# https://openai.com/blog/instruction-following
# openai.com https://openai.com/blog/instruction-following
# https://openai.com/blog/chatgpt#content
# openai.com https://openai.com/blog/chatgpt#content
# https://openai.com/blog/openai-baselines-ppo
# openai.com https://openai.com/blog/openai-baselines-ppo
# https://openai.com/blog/chatgpt#OpenAI
# openai.com https://openai.com/blog/chatgpt#OpenAI
# https://openai.com/api
# openai.com https://openai.com/api
# https://openai.com/product#made-for-developers
# openai.com https://openai.com/product#made-for-developers
# https://openai.com/product#content
# openai.com https://openai.com/product#content
# https://openai.com/careers/software-engineer-front-endux
# openai.com https://openai.com/careers/software-engineer-front-endux
# https://openai.com/careers/software-engineer-front-endux#content
# openai.com https://openai.com/careers/software-engineer-front-endux#content
# https://openai.com/careers/research-engineer
# openai.com https://openai.com/careers/research-engineer
# https://openai.com/blog/image-gpt
# openai.com https://openai.com/blog/image-gpt
# https://openai.com/blog/jukebox
# ...
# openai.com https://openai.com/blog/how-should-ai-systems-behave#OpenAI
# https://openai.com/blog/bug-bounty-program
# openai.com https://openai.com/blog/bug-bounty-program
# https://openai.com/blog/bug-bounty-program#content
# openai.com https://openai.com/blog/bug-bounty-program#content
# https://openai.com/careers/search?c=security
# https://openai.com/blog/bug-bounty-program#OpenAI
# openai.com https://openai.com/blog/bug-bounty-program#OpenAI
# https://openai.com/research/point-e
# openai.com https://openai.com/research/point-e
# https://openai.com/research/point-e#content
# openai.com https://openai.com/research/point-e#content
# https://openai.com/research?models=point-e
# https://openai.com/brand
# openai.com https://openai.com/brand
# https://openai.com/brand#content
# openai.com https://openai.com/brand#content
# https://openai.com/charter
# openai.com https://openai.com/charter
# https://openai.com/charter#content
# openai.com https://openai.com/charter#content
# https://openai.com/product
# openai.com https://openai.com/product
# https://openai.com/#content
# openai.com https://openai.com/#content
# https://openai.com/blog/new-and-improved-embedding-model
# openai.com https://openai.com/blog/new-and-improved-embedding-model
# https://openai.com/blog/new-and-improved-embedding-model#RyanGreene
# openai.com https://openai.com/blog/new-and-improved-embedding-model#RyanGreene
# https://openai.com/blog/new-and-improved-embedding-model#content
# openai.com https://openai.com/blog/new-and-improved-embedding-model#content
# https://openai.com/blog?authors=ryan-greene
# https://openai.com/blog/new-and-improved-embedding-model#LilianWeng
# openai.com https://openai.com/blog/new-and-improved-embedding-model#LilianWeng
# https://openai.com/blog?authors=ted-sanders
# https://openai.com/blog/new-and-improved-embedding-model#TedSanders
# openai.com https://openai.com/blog/new-and-improved-embedding-model#TedSanders
# https://openai.com/blog/new-and-improved-embedding-model#ArvindNeelakantan
# openai.com https://openai.com/blog/new-and-improved-embedding-model#ArvindNeelakantan
# https://openai.com/careers
# openai.com https://openai.com/careers
# https://openai.com/blog/dall-e-now-available-without-waitlist
# openai.com https://openai.com/blog/dall-e-now-available-without-waitlist
# https://openai.com/blog/dall-e-2-update
# openai.com https://openai.com/blog/dall-e-2-update
# https://openai.com/blog/dall-e-2-update#OpenAI
# openai.com https://openai.com/blog/dall-e-2-update#OpenAI
# https://openai.com/blog/dall-e-2-update#JoanneJang
# openai.com https://openai.com/blog/dall-e-2-update#JoanneJang
# https://openai.com/blog/dall-e-2-update#content
# openai.com https://openai.com/blog/dall-e-2-update#content
# https://openai.com/blog/dall-e-now-available-in-beta
# openai.com https://openai.com/blog/dall-e-now-available-in-beta
# https://openai.com/blog/dall-e-now-available-in-beta#content
# openai.com https://openai.com/blog/dall-e-now-available-in-beta#content
# https://openai.com/blog/dall-e-now-available-in-beta#OpenAI
# openai.com https://openai.com/blog/dall-e-now-available-in-beta#OpenAI
# https://openai.com/blog/dall-e-now-available-without-waitlist#content
# openai.com https://openai.com/blog/dall-e-now-available-without-waitlist#content
# https://openai.com/blog/dall-e-now-available-without-waitlist#OpenAI
# openai.com https://openai.com/blog/dall-e-now-available-without-waitlist#OpenAI
# https://openai.com/research/gpt-4
# openai.com https://openai.com/research/gpt-4
# https://openai.com/research/gpt-4#content
# openai.com https://openai.com/research/gpt-4#content
# https://openai.com/research?models=gpt-4
# https://openai.com/waitlist/gpt-4
# openai.com https://openai.com/waitlist/gpt-4
# https://openai.com/research
# openai.com https://openai.com/research
# https://openai.com/research/a-hazard-analysis-framework-for-code-synthesis-large-language-models
# openai.com https://openai.com/research/a-hazard-analysis-framework-for-code-synthesis-large-language-models
# https://openai.com/research?models=openai-codex
# https://openai.com/research?authors=joshua-achiam
# https://openai.com/research/a-hazard-analysis-framework-for-code-synthesis-large-language-models#content
# openai.com https://openai.com/research/a-hazard-analysis-framework-for-code-synthesis-large-language-models#content
# https://openai.com/research?authors=heidy-khlaaf
# https://openai.com/research/critiques
# openai.com https://openai.com/research/critiques
# https://openai.com/research/measuring-goodharts-law
# openai.com https://openai.com/research/measuring-goodharts-law
# https://openai.com/blog/learning-to-summarize-with-human-feedback/#optimizingtherewardmodel
# openai.com https://openai.com/blog/learning-to-summarize-with-human-feedback/#optimizingtherewardmodel
# https://openai.com/research/measuring-goodharts-law#content
# openai.com https://openai.com/research/measuring-goodharts-law#content
# https://openai.com/research/gpts-are-gpts
# openai.com https://openai.com/research/gpts-are-gpts
# https://openai.com/research/gpts-are-gpts#content
# openai.com https://openai.com/research/gpts-are-gpts#content
# https://openai.com/research/evolution-through-large-models
# openai.com https://openai.com/research/evolution-through-large-models
# https://openai.com/research?authors=jonathan-gordon
# https://openai.com/research/evolution-through-large-models#content
# openai.com https://openai.com/research/evolution-through-large-models#content
# https://openai.com/research?authors=joel-lehman
# https://openai.com/research?authors=cathy-yeh
# https://openai.com/research?authors=kamal-ndousse
# https://openai.com/research?authors=shawn-jain
# https://openai.com/research?authors=kenneth-o-stanley
# https://openai.com/research/scaling-laws-for-reward-model-overoptimization
# openai.com https://openai.com/research/scaling-laws-for-reward-model-overoptimization
# https://openai.com/research/scaling-laws-for-reward-model-overoptimization#content
# openai.com https://openai.com/research/scaling-laws-for-reward-model-overoptimization#content
# https://openai.com/research/vpt
# openai.com https://openai.com/research/vpt
# https://openai.com/research?authors=peter-zhokhov
# https://openai.com/research?authors=jeff-clune
# https://openai.com/research/vpt#content
# openai.com https://openai.com/research/vpt#content
# https://openai.com/research?authors=raul-sampedro
# https://openai.com/research?authors=joost-huizinga
# https://openai.com/research/economic-impacts
# openai.com https://openai.com/research/economic-impacts
# https://openai.com/research/economic-impacts#content
# openai.com https://openai.com/research/economic-impacts#content
# https://openai.com/research/techniques-for-training-large-neural-networks
# openai.com https://openai.com/research/techniques-for-training-large-neural-networks
# https://openai.com/research/techniques-for-training-large-neural-networks#content
# openai.com https://openai.com/research/techniques-for-training-large-neural-networks#content
# https://openai.com/research/teaching-models-to-express-their-uncertainty-in-words
# openai.com https://openai.com/research/teaching-models-to-express-their-uncertainty-in-words
# https://openai.com/research/teaching-models-to-express-their-uncertainty-in-words#content
# openai.com https://openai.com/research/teaching-models-to-express-their-uncertainty-in-words#content
# https://openai.com/research?authors=owain-evans
# https://openai.com/research?authors=stephanie-lin
# https://openai.com/research/efficient-training-of-language-models-to-fill-in-the-middle
# openai.com https://openai.com/research/efficient-training-of-language-models-to-fill-in-the-middle
# https://openai.com/research?authors=mohammad-bavarian
# https://openai.com/research/efficient-training-of-language-models-to-fill-in-the-middle#content
# https://openai.com/customer-stories#content
# openai.com https://openai.com/customer-stories#content
# https://openai.com/research/forecasting-misuse
# openai.com https://openai.com/research/forecasting-misuse
# https://openai.com/product/dall-e-2
# openai.com https://openai.com/product/dall-e-2
# https://openai.com/blog/gpt-3-edit-insert
# openai.com https://openai.com/blog/gpt-3-edit-insert
# https://openai.com/blog?authors=henrique-ponde
# https://openai.com/blog?authors=mohammad-bavarian
# https://openai.com/blog/gpt-3-edit-insert#MohammadBavarian
# openai.com https://openai.com/blog/gpt-3-edit-insert#MohammadBavarian
# https://openai.com/blog?authors=heewoo-jun
# https://openai.com/blog?authors=angela-jiang
# https://openai.com/blog/gpt-3-edit-insert#HeewooJun
# openai.com https://openai.com/blog/gpt-3-edit-insert#HeewooJun
# https://openai.com/api/pricing
# openai.com https://openai.com/api/pricing
# https://openai.com/pricing#language-models
# openai.com https://openai.com/pricing#language-models
# https://openai.com/pricing#content
# openai.com https://openai.com/pricing#content
# https://openai.com/blog/gpt-3-edit-insert#content
# openai.com https://openai.com/blog/gpt-3-edit-insert#content
# https://openai.com/blog/gpt-3-edit-insert#HenriquePondé
# openai.com https://openai.com/blog/gpt-3-edit-insert#HenriquePondé
# https://openai.com/blog/gpt-3-edit-insert#AngelaJiang
# openai.com https://openai.com/blog/gpt-3-edit-insert#AngelaJiang
# https://openai.com/security
# openai.com https://openai.com/security
# https://openai.com/security#content
# openai.com https://openai.com/security#content
# https://openai.com/pricing
# openai.com https://openai.com/pricing
# https://openai.com/product/chatgpt
# openai.com https://openai.com/product/chatgpt
# https://openai.com/product/chatgpt#content
# openai.com https://openai.com/product/chatgpt#content
# https://openai.com/safety-standards
# openai.com https://openai.com/safety-standards
# https://openai.com/safety-standards#content
# openai.com https://openai.com/safety-standards#content
# https://openai.com/safety
# openai.com https://openai.com/safety
# https://openai.com/blog/new-and-improved-content-moderation-tooling
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling
# https://openai.com/blog/new-and-improved-content-moderation-tooling#TynaEloundou
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#TynaEloundou
# https://openai.com/blog/new-and-improved-content-moderation-tooling#content
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#content
# https://openai.com/blog?authors=teddy-lee
# https://openai.com/blog/new-and-improved-content-moderation-tooling#TeddyLee
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#TeddyLee
# https://openai.com/blog/new-and-improved-content-moderation-tooling#ChongZhang
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#ChongZhang
# https://openai.com/blog/new-and-improved-content-moderation-tooling#StevenAdler
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#StevenAdler
# https://openai.com/blog/new-and-improved-content-moderation-tooling#AngelaJiang
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#AngelaJiang
# https://openai.com/blog?authors=todor-markov
# https://openai.com/blog/new-and-improved-content-moderation-tooling#TodorMarkov
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#TodorMarkov
# https://openai.com/blog/new-and-improved-content-moderation-tooling#LilianWeng
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#LilianWeng
# https://openai.com/blog?authors=steven-adler
# https://openai.com/blog/customized-gpt-3
# openai.com https://openai.com/blog/customized-gpt-3
# https://openai.com/blog/customizing-gpt-3#example
# openai.com https://openai.com/blog/customizing-gpt-3#example
# https://openai.com/blog/customizing-gpt-3#LukeMiller
# openai.com https://openai.com/blog/customizing-gpt-3#LukeMiller
# https://openai.com/blog/customizing-gpt-3#RachelLim
# openai.com https://openai.com/blog/customizing-gpt-3#RachelLim
# https://openai.com/blog/customizing-gpt-3#MichaelWu
# openai.com https://openai.com/blog/customizing-gpt-3#MichaelWu
# https://openai.com/blog?authors=michael-wu
# https://openai.com/blog/customizing-gpt-3#content
# openai.com https://openai.com/blog/customizing-gpt-3#content
# https://openai.com/blog?authors=chong-zhang
# https://openai.com/blog/new-and-improved-content-moderation-tooling#SandhiniAgarwal
# openai.com https://openai.com/blog/new-and-improved-content-moderation-tooling#SandhiniAgarwal

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

# Get all the text files in the text directory
for file in os.listdir("text/" + domain + "/"):

    # Open the file and read the text
    with open("text/" + domain + "/" + file, "r", encoding="UTF-8") as f:
        text = f.read()

        # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
        texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()
# Out:
# C:\Users\12par\AppData\Local\Temp\ipykernel_31444\2931785837.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   serie = serie.str.replace('\\n', ' ')
#            fname                                               text
# 0                 .  OpenAI   CloseSearch Submit Skip to main co...
# 1       #content  #content.  OpenAI   CloseSearch Submit Skip to...
# 2                 .  OpenAI   CloseSearch Submit Skip to main co...
# 3  about#content  about#content.  About   CloseSearch Submit Ski...
# 4          about  about.  About   CloseSearch Submit Skip to mai...

# %%
df.sample(100)
# Out:
#                                                  fname  \
# 515                           research jukebox#content
# 62           blog dall e now available in beta#content
# 502                      research image gpt#conclusion
# 517  research language model safety and misuse#content
# 81   blog discovering the minutiae of backend syste...
# ..                                                 ...
# 306               careers manager scientist deployment
# 390                      customer stories khan academy
# 31                                blog chatgpt plugins
# 545              research openai baselines dqn#content
# 573                     research retro contest results
#
#                                                   text
# 515  research jukebox#content.  Jukebox   CloseSear...
# 62   blog dall e now available in beta#content.  DA...
# 502  research image gpt#conclusion.  Image GPT   Cl...
# 517  research language model safety and misuse#cont...
# 81   blog discovering the minutiae of backend syste...
# ..                                                 ...
# 306  careers manager scientist deployment.  Manager...
# 390  customer stories khan academy.  Khan Academy  ...
# 31   blog chatgpt plugins.  ChatGPT plugins   Close...
# 545  research openai baselines dqn#content.  OpenAI...
# 573  research retro contest results.  Retro Contest...
#
# [100 rows x 2 columns]

# %%
df.fname[75]
# Out:
# 'blog democratic inputs to ai#LamaAhmad'

# %%
df.text[75]
# Out:
# 'blog democratic inputs to ai#LamaAhmad.  Democratic Inputs to AI   CloseSearch Submit Skip to main contentSite NavigationResearchOverviewIndexProductOverviewChatGPTGPT-4DALLÂ·E 2Customer storiesSafety standardsPricingDevelopersOverviewDocumentationAPI referenceExamplesSafetyCompanyAboutBlogCareersCharterSecuritySearch Navigation quick links Log inSign upMenu Mobile Navigation CloseSite NavigationResearchProductDevelopersSafetyCompany Quick Links Log inSign upSearch Submit Democratic Inputs to AIOur nonprofit organization, OpenAI, Inc., is launching a program to award ten $100,000 grants to fund experiments in setting up a democratic process for deciding what rules AI systems should follow, within the bounds defined by the law.Illustration: Justin Jay WangMay 25, 2023AuthorsWojciech ZarembaArka DharLama AhmadTyna EloundouShibani SanturkarSandhini AgarwalJade LeungAnnouncements,Â\xa0Responsible AIAI will have significant, far-reaching economic and societal impacts. Technology shapes the lives of individuals, how we interact with one another, and how society as a whole evolves. We believe that decisions about how AI behaves should be shaped by diverse perspectives reflecting the public interest.Â\xa0â\x80\x8bâ\x80\x8bLaws encode values and norms to regulate behavior. Beyond a legal framework, AI, much like society, needs more intricate and adaptive guidelines for its conduct. For example: under what conditions should AI systems condemn or criticize public figures, given different opinions across groups regarding those figures? How should disputed views be represented in AI outputs? Should AI by default reflect the persona of a median individual in the world, the userâ\x80\x99s country, the userâ\x80\x99s demographic, or something entirely different? No single individual, company, or even country should dictate these decisions.Â\xa0AGI should benefit all of humanity and be shaped to be as inclusive as possible. We are launching this grant program to take a first step in this direction. We are seeking teams from across the world to develop proof-of-concepts for a democratic process that could answer questions about what rules AI systems should follow. We want to learn from these experiments, and use them as the basis for a more global, and more ambitious process going forward. While these initial experiments are not (at least for now) intended to be binding for decisions, we hope that they explore decision relevant questions and build novel democratic tools that can more directly inform decisions in the future.The governance of the most powerful systems, as well as decisions regarding their deployment, must have strong public oversight. This grant represents a step to establish democratic processes for overseeing AGI and, ultimately, superintelligence. It will be provided by the OpenAI non-profit organization, and the results of the studies will be freely accessible.What do we mean by a â\x80\x9cdemocratic processâ\x80\x9d?By â\x80\x9cdemocratic processâ\x80\x9d, we mean a process in which a broadly representative group of people[^footnote-1]Â\xa0exchange opinions, engage in deliberative discussions[^footnote-2],Â\xa0and ultimately decide on an outcome via a transparent decision making process[^footnote-3]. There are many ways such a process could be structured â\x80\x94 we encourage applicants to be innovative, building off known methodologies, and coming up with wholly new approaches. Examples of creative approaches that inspire us include Wikipedia, Twitter Community Notes, DemocracyNext, Platform Assemblies, MetaGov, RadicalxChange, People Powered, Collective Response Systems, and pol.is. Another notable ongoing effort is led by the Collective Intelligence Project (CIP), with whom we are partnering on public input to AI, contributing to their upcoming Alignment Assemblies. We also encourage applicants to envision how AI could enhance the democratic process. For example, AI could enable more efficient communication among numero ...
